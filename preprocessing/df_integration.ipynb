# %%
import pandas as pd
import numpy as np
df24=pd.read_pickle(f"../df24.pkl")
df23=pd.read_pickle(f"../df23.pkl")
df22=pd.read_pickle(f"../df22.pkl")

# %%
df24.columns
# Out:
# Index(['dm', 'sex', 'age', 'edu', 'income', 'job', 'glu', 'hba1c', 'hdl', 'tg',
#        'ldl', 'sbp', 'wc', 'bmi', 'wk_smk', 'wk_alc', 'wk_mvpa_play',
#        'wk_walk', 'wk_sleep', 'stress', 'wk_break', 'wk_lunch', 'wk_dinner',
#        'wk_veg1', 'wk_veg2', 'wk_fruit'],
#       dtype='object')

# %%
df = pd.concat([df22, df23, df24], axis=0)
df.shape
# Out:
# (13796, 26)

# %%
df['wk_alc'].value_counts()
# Out:
# wk_alc
# 0.0000     3948
# 0.1875     1879
# 1.1250      765
# 0.3750      706
# 2.6250      699
# 6.0000      662
# 20.0000     507
# 0.4375      479
# 7.5000      463
# 25.0000     462
# 4.1250      432
# 0.8750      348
# 8.7500      343
# 3.7500      299
# 13.7500     291
# 32.0000     244
# 40.0000     205
# 2.0000      179
# 1.3750      168
# 1.0000      156
# 0.6875      141
# 14.0000     130
# 2.5000      107
# 1.2500       96
# 22.0000      87
# Name: count, dtype: int64

# %%
df['dm'].value_counts()
# Out:
# dm
# 0    7222
# 1    4471
# 2    2103
# Name: count, dtype: int64

# %%
df.to_pickle("../df.pkl")
